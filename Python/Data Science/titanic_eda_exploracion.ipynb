# %% [markdown]
# # 🔍 Titanic - Exploración de Datos (EDA)
# Este notebook te guiará a través de un Análisis Exploratorio de Datos (EDA) utilizando el dataset del Titanic.
#
# Incluye:
# - Estadísticas descriptivas
# - Identificación de patrones
# - Primeros insights de los datos

# %% [markdown]
# ## 📥 1. Carga del dataset
# Sube el archivo `Titanic-Dataset.csv` al entorno de ejecución.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('Titanic-Dataset.csv')
df.head()

# %% [markdown]
# ## 📊 2. Estadísticas descriptivas

# %%
# Vista general
df.describe()

# %%
# Conteo por clase y sexo
df['Pclass'].value_counts()
df['Sex'].value_counts()
df['Survived'].value_counts(normalize=True)

# %% [markdown]
# ## 🔎 3. Identificación de patrones y relaciones

# %%
# Supervivencia por sexo
sns.countplot(data=df, x='Sex', hue='Survived')
plt.title('Supervivencia por Sexo')
plt.show()

# %%
# Supervivencia por clase
sns.countplot(data=df, x='Pclass', hue='Survived')
plt.title('Supervivencia por Clase')
plt.show()

# %%
# Distribución de edad por supervivencia
sns.histplot(data=df, x='Age', hue='Survived', bins=30, kde=True)
plt.title('Distribución de Edad por Supervivencia')
plt.show()

# %%
# Mapa de calor de correlación
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Matriz de Correlaciones')
plt.show()

# %% [markdown]
# ## ✅ Conclusiones preliminares
# - ¿Qué variables parecen estar asociadas con la supervivencia?
# - ¿Qué distribución tiene la edad?
# - ¿Qué clases tuvieron mayor mortalidad?
