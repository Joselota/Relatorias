# %%
# ====== Config ======
EXCEL_IN    = "detalle_pn1.xlsx"                # archivo con las URLs
COL_URL     = "URL Ficha"                       # nombre EXACTO de la columna con la URL
CSV_OUT     = "num_empleados_caratula_pn1.csv"  # salida
PERIODO     = "12"
ANIO        = "2024"
CONCURRENCY = 4                                  # páginas en paralelo
HEADLESS    = True                               # pon False si quieres ver el navegador

# ====== Código ======
import time, asyncio, nest_asyncio, pandas as pd
from datetime import datetime
from playwright.async_api import async_playwright

nest_asyncio.apply()

ROW_SELECTOR = "div#caratula table tr:has(td:has-text('1.15.00.00'))"
EMP_FALLBACK = "div#caratula table tr:has(td:has-text('Empleados'))"

async def setup_browser(headless=HEADLESS):
    p = await async_playwright().start()
    browser = await p.chromium.launch(headless=headless)
    ctx = await browser.new_context(
        locale="es-CL",
        user_agent=("Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 "
                    "(KHTML, like Gecko) Chrome/120 Safari/537.36"),
    )
    # bloquear recursos pesados
    await ctx.route("**/*", lambda route, request: (
        route.abort()
        if request.resource_type in {"image", "stylesheet", "font", "media"}
        else route.continue_()
    ))
    return p, browser, ctx

async def scrape_url(ctx, url, periodo=PERIODO, anio=ANIO, timeout_ms=30000):
    """Devuelve {'URL': url, 'N° de Empleados': valor}"""
    page = await ctx.new_page()
    page.set_default_timeout(timeout_ms)
    try:
        await page.goto(url, wait_until="domcontentloaded")

        # setear selects + Consultar (si existen)
        try:
            form = page.locator("form").first
            selects = form.locator("select")
            if await selects.count() >= 1:
                await selects.nth(0).select_option(value=str(periodo))
            if await selects.count() >= 2:
                try:
                    await selects.nth(1).select_option(value=str(anio))
                except:
                    await selects.nth(1).select_option(label=str(anio))
            # click consultar
            try:
                await form.get_by_role("button", name="Consultar").click()
            except:
                try:
                    await page.locator("button:has-text('Consultar')").click()
                except:
                    await page.locator("input[type=submit]").first.click()
        except Exception:
            pass

        # esperar directamente la fila (o la tabla si no aparece)
        row = page.locator(ROW_SELECTOR).first
        try:
            await row.wait_for(state="visible", timeout=15000)
        except:
            await page.wait_for_selector("div#caratula table", timeout=15000)
            row = page.locator(EMP_FALLBACK).first

        # extraer último <td> de la fila
        valor = None
        if await row.count() > 0:
            tds = row.locator("td")
            n = await tds.count()
            if n > 0:
                valor = (await tds.nth(n-1).inner_text()).strip()

        return {"URL": url, "N° de Empleados": valor}
    except Exception:
        return {"URL": url, "N° de Empleados": None}
    finally:
        try:
            await page.close()
        except:
            pass

async def run_batch(urls, concurrency=CONCURRENCY):
    p, browser, ctx = await setup_browser()
    sem = asyncio.Semaphore(concurrency)

    total = len(urls)
    done = 0
    start_ts = time.time()
    results = []

    async def worker(u, idx):
        nonlocal done
        async with sem:
            t0 = time.time()
            res = await scrape_url(ctx, u)
            elapsed = time.time() - t0
            done += 1

            # imprimir progreso (flush inmediato)
            estado = "OK" if res.get("N° de Empleados") not in (None, "") else "—"
            print(f"[{done}/{total}] {estado}  {elapsed:5.2f}s  -> {u}", flush=True)

            results.append(res)

    try:
        tasks = [asyncio.create_task(worker(u, i)) for i, u in enumerate(urls)]
        # ir mostrando progreso a medida que terminan
        for fut in asyncio.as_completed(tasks):
            await fut

        total_elapsed = time.time() - start_ts
        print(f"\nFin batch: {total} URLs en {total_elapsed:0.1f}s  (~{total/total_elapsed:0.2f} urls/s)", flush=True)
    finally:
        try:  await ctx.close()
        except: pass
        try:  await browser.close()
        except: pass
        try:  await p.stop()
        except: pass
    return results

# ====== Leer Excel, ejecutar y guardar ======
df_in = pd.read_excel(EXCEL_IN)
if COL_URL not in df_in.columns:
    raise ValueError(f"No encontré la columna '{COL_URL}' en {EXCEL_IN}")

urls = df_in[COL_URL].dropna().astype(str).tolist()

print(f"Inicio: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"Total URLs: {len(urls)} | Concurrency: {CONCURRENCY} | Headless: {HEADLESS}\n")

results = await run_batch(urls)

df_out = pd.DataFrame(results)
df_out.to_csv(CSV_OUT, index=False, encoding="utf-8-sig")
print(f"\n✅ Listo: {CSV_OUT} ({len(df_out)} filas)")
display(df_out.head())
# Out:
# Inicio: 2025-09-20 19:52:08
# Total URLs: 999 | Concurrency: 4 | Headless: True
#
# [1/999] —  31.83s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7827318&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAG3AAf&control=svs&pestania=3
# [2/999] —  31.84s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7827318&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAG3AAf&control=svs&pestania=3
# [3/999] —  31.95s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7827318&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAG3AAf&control=svs&pestania=3
# [4/999] —  32.14s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7827318&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAG3AAf&control=svs&pestania=3
# [5/999] —  31.34s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=5916556&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOSAAD&control=svs&pestania=3
# [6/999] —  31.45s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=20079632&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWPOAAL&control=svs&pestania=3
# [7/999] —  31.73s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=8971448&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAGkAAk&control=svs&pestania=3
# [8/999] —  31.67s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=10421164&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAGKAAT&control=svs&pestania=3
# [9/999] —  31.21s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=4776668&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAFuAAO&control=svs&pestania=3
# [10/999] —  31.09s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=5245132&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAEGAAW&control=svs&pestania=3
# [11/999] —  31.33s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=9147026&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAGTAAc&control=svs&pestania=3
# [12/999] —  31.77s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7864632&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAG%2FAAS&control=svs&pestania=3
# [13/999] —  30.84s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=3643433&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAEJAAs&control=svs&pestania=3
# [14/999] —  30.92s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=13426902&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWPoAAL&control=svs&pestania=3
# [15/999] —  31.17s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7526505&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWPNAAH&control=svs&pestania=3
# [16/999] —  30.95s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=10585286&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOvAAa&control=svs&pestania=3
# [17/999] —  30.88s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=5706483&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAFSAAj&control=svs&pestania=3
# [18/999] —  30.90s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=5846881&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAEyAAg&control=svs&pestania=3
# [19/999] —  30.86s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=16672609&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOoAAQ&control=svs&pestania=3
# [20/999] —  30.97s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7452615&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAFLAAH&control=svs&pestania=3
# [21/999] —  30.87s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=5817926&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAF8AAO&control=svs&pestania=3
# [22/999] —  30.85s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=6067873&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAEZAAK&control=svs&pestania=3
# [23/999] —  30.86s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=13640971&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOzAAZ&control=svs&pestania=3
# [24/999] —  30.96s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=8623110&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOQAAM&control=svs&pestania=3
# [25/999] —  30.87s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=8895597&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOxAAQ&control=svs&pestania=3
# [26/999] —  30.88s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7400494&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWO2AAD&control=svs&pestania=3
# [27/999] —  30.97s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=8606103&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOjAAD&control=svs&pestania=3
# [28/999] —  30.93s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=
grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAFhAAj&control=svs&pestania=3
# [73/999] —  30.75s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=10009332&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAF+AAX&control=svs&pestania=3
# [74/999] —  30.71s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=6973096&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOiAAm&control=svs&pestania=3
# [75/999] —  30.75s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=14004389&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWO9AAE&control=svs&pestania=3
# [76/999] —  30.68s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=8821717&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAHPAAG&control=svs&pestania=3
# [77/999] —  30.79s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=6659996&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAHyAAX&control=svs&pestania=3
# [78/999] —  30.85s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7406524&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAGOAAX&control=svs&pestania=3
# [79/999] —  30.93s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=6377703&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWO8AAH&control=svs&pestania=3
# [80/999] —  31.10s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=8019706&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAGfAAH&control=svs&pestania=3
# [81/999] —  30.76s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=14250407&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOXAAP&control=svs&pestania=3
# [82/999] —  30.81s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=10930166&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWO+AAP&control=svs&pestania=3
# [83/999] —  30.67s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=14398091&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAHGAAI&control=svs&pestania=3
# [84/999] —  30.69s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=15175495&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOkAAM&control=svs&pestania=3
# [85/999] —  30.80s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=8746562&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOiAAU&control=svs&pestania=3
# [86/999] —  30.82s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=8608824&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOeAAN&control=svs&pestania=3
# [87/999] —  31.11s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=17594774&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWPsAAG&control=svs&pestania=3
# [88/999] —  31.09s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7446696&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAFLAAE&control=svs&pestania=3
# [89/999] —  30.68s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7401500&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAGOAAM&control=svs&pestania=3
# [90/999] —  30.70s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=8467659&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAFWAAZ&control=svs&pestania=3
# [91/999] —  30.65s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=5206745&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAF7AAr&control=svs&pestania=3
# [92/999] —  30.65s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=17318745&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWPBAAF&control=svs&pestania=3
# [93/999] —  30.76s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=10213792&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAHTAAS&control=svs&pestania=3
# [94/999] —  30.69s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=12488432&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOxAAe&control=svs&pestania=3
# [95/999] —  30.66s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=10258427&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOLAAY&control=svs&pestania=3
# [96/999] —  30.65s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=11196917&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOqAAH&control=svs&pestania=3
# [97/999] —  30.80s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=5424431&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAGoAAm&control=svs&pestania=3
# [98/999] —  30.77s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=10775999&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOuAAb&control=svs&pestania=3
# [99/999] —  30.65s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=17991636&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWPwAAD&control=svs&pestania=3
# [100/999] —  30.61s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=8331073&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOvAAJ&control=svs&pestania=3
# [101/999] —  30.78s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7462528&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAFXAAq&control=svs&pestania=3
# [102/999] —  30.65s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=9166084&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAFKAAJ&control=svs&pestania=3
# [103/999] —  30.62s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=6573547&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAG1AAb&control=svs&pestania=3
# [104/999] —  30.79s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=14166179&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOsAAe&control=svs&pestania=3
# [105/999] —  31.11s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=13237426&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOjAAS&control=svs&pestania=3
# [106/999] —  30.83s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=11226869&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOVAAc&control=svs&pestania=3
# [107/999] —  30.74s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=9831832&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAH+AAZ&control=svs&pestania=3
# [108/999] —  30.68s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7188059&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOkAAD&control=svs&pestania=3
# [109/999] —  30.68s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=4017804&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAEtAAo&control=svs&pestania=3
# [110/999] —  30.97s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=12313928&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAHVAAC&control=svs&pestania=3
# [111/999] —  30.77s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=6821357&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAHyAAR&control=svs&pestania=3
# [112/999] —  30.81s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=6128012&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAGMAAg&control=svs&pestania=3
# [113/999] —  30.64s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=10119396&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWO0AAg&control=svs&pestania=3
# [114/999] —  30.75s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=10388795&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOZAAN&control=svs&pestania=3
# [115/999] —  30.80s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=11497154&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOiAAa&control=svs&pestania=3
# [116/999] —  30.80s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=12329613&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOgAAJ&control=svs&pestania=3
# [117/999] —  30.76s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=9297788&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWO4AAe&control=svs&pestania=3
# [118/999] —  30.86s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=12689785&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWPCAAK&control=svs&pestania=3
# [119/999] —  30.81s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=
999] —  30.71s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=4945811&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAENAAg&control=svs&pestania=3
# [990/999] —  30.69s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=6585757&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOSAAX&control=svs&pestania=3
# [991/999] —  30.68s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=10430121&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAGJAAS&control=svs&pestania=3
# [992/999] —  30.63s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=18984809&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOzAAO&control=svs&pestania=3
# [993/999] —  30.70s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7547007&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAHWAAb&control=svs&pestania=3
# [994/999] —  30.69s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=8425632&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWO7AAL&control=svs&pestania=3
# [995/999] —  30.68s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=10618679&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWPQAAD&control=svs&pestania=3
# [996/999] —  30.68s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7826177&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAH2AAK&control=svs&pestania=3
# [997/999] —  30.66s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=9714539&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOwAAd&control=svs&pestania=3
# [998/999] —  30.64s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=9766514&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWP%2FAAI&control=svs&pestania=3
# [999/999] —  30.67s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=13992199&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWPuAAF&control=svs&pestania=3
#
# Fin batch: 999 URLs en 10589.1s  (~0.09 urls/s)
#
# ✅ Listo: num_empleados_caratula_pn1.csv (999 filas)
#                                                  URL N° de Empleados
# 0  https://www.cmfchile.cl/institucional/mercados...            None
# 1  https://www.cmfchile.cl/institucional/mercados...            None
# 2  https://www.cmfchile.cl/institucional/mercados...            None
# 3  https://www.cmfchile.cl/institucional/mercados...            None
# 4  https://www.cmfchile.cl/institucional/mercados...            None

# %% [markdown]
# <h2>2</h2>

# %%
# ====== Config ======
EXCEL_IN    = "detalle_pn2.xlsx"                # archivo con las URLs
COL_URL     = "URL Ficha"                       # nombre EXACTO de la columna con la URL
CSV_OUT     = "num_empleados_caratula_pn2.csv"  # salida
PERIODO     = "12"
ANIO        = "2024"
CONCURRENCY = 4                                  # páginas en paralelo
HEADLESS    = True                               # pon False si quieres ver el navegador

# ====== Código ======
import time, asyncio, nest_asyncio, pandas as pd
from datetime import datetime
from playwright.async_api import async_playwright

nest_asyncio.apply()

ROW_SELECTOR = "div#caratula table tr:has(td:has-text('1.15.00.00'))"
EMP_FALLBACK = "div#caratula table tr:has(td:has-text('Empleados'))"

async def setup_browser(headless=HEADLESS):
    p = await async_playwright().start()
    browser = await p.chromium.launch(headless=headless)
    ctx = await browser.new_context(
        locale="es-CL",
        user_agent=("Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 "
                    "(KHTML, like Gecko) Chrome/120 Safari/537.36"),
    )
    # bloquear recursos pesados
    await ctx.route("**/*", lambda route, request: (
        route.abort()
        if request.resource_type in {"image", "stylesheet", "font", "media"}
        else route.continue_()
    ))
    return p, browser, ctx

async def scrape_url(ctx, url, periodo=PERIODO, anio=ANIO, timeout_ms=30000):
    """Devuelve {'URL': url, 'N° de Empleados': valor}"""
    page = await ctx.new_page()
    page.set_default_timeout(timeout_ms)
    try:
        await page.goto(url, wait_until="domcontentloaded")

        # setear selects + Consultar (si existen)
        try:
            form = page.locator("form").first
            selects = form.locator("select")
            if await selects.count() >= 1:
                await selects.nth(0).select_option(value=str(periodo))
            if await selects.count() >= 2:
                try:
                    await selects.nth(1).select_option(value=str(anio))
                except:
                    await selects.nth(1).select_option(label=str(anio))
            # click consultar
            try:
                await form.get_by_role("button", name="Consultar").click()
            except:
                try:
                    await page.locator("button:has-text('Consultar')").click()
                except:
                    await page.locator("input[type=submit]").first.click()
        except Exception:
            pass

        # esperar directamente la fila (o la tabla si no aparece)
        row = page.locator(ROW_SELECTOR).first
        try:
            await row.wait_for(state="visible", timeout=15000)
        except:
            await page.wait_for_selector("div#caratula table", timeout=15000)
            row = page.locator(EMP_FALLBACK).first

        # extraer último <td> de la fila
        valor = None
        if await row.count() > 0:
            tds = row.locator("td")
            n = await tds.count()
            if n > 0:
                valor = (await tds.nth(n-1).inner_text()).strip()

        return {"URL": url, "N° de Empleados": valor}
    except Exception:
        return {"URL": url, "N° de Empleados": None}
    finally:
        try:
            await page.close()
        except:
            pass

async def run_batch(urls, concurrency=CONCURRENCY):
    p, browser, ctx = await setup_browser()
    sem = asyncio.Semaphore(concurrency)

    total = len(urls)
    done = 0
    start_ts = time.time()
    results = []

    async def worker(u, idx):
        nonlocal done
        async with sem:
            t0 = time.time()
            res = await scrape_url(ctx, u)
            elapsed = time.time() - t0
            done += 1

            # imprimir progreso (flush inmediato)
            estado = "OK" if res.get("N° de Empleados") not in (None, "") else "—"
            print(f"[{done}/{total}] {estado}  {elapsed:5.2f}s  -> {u}", flush=True)

            results.append(res)

    try:
        tasks = [asyncio.create_task(worker(u, i)) for i, u in enumerate(urls)]
        # ir mostrando progreso a medida que terminan
        for fut in asyncio.as_completed(tasks):
            await fut

        total_elapsed = time.time() - start_ts
        print(f"\nFin batch: {total} URLs en {total_elapsed:0.1f}s  (~{total/total_elapsed:0.2f} urls/s)", flush=True)
    finally:
        try:  await ctx.close()
        except: pass
        try:  await browser.close()
        except: pass
        try:  await p.stop()
        except: pass
    return results

# ====== Leer Excel, ejecutar y guardar ======
df_in = pd.read_excel(EXCEL_IN)
if COL_URL not in df_in.columns:
    raise ValueError(f"No encontré la columna '{COL_URL}' en {EXCEL_IN}")

urls = df_in[COL_URL].dropna().astype(str).tolist()

print(f"Inicio: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"Total URLs: {len(urls)} | Concurrency: {CONCURRENCY} | Headless: {HEADLESS}\n")

results = await run_batch(urls)

df_out = pd.DataFrame(results)
df_out.to_csv(CSV_OUT, index=False, encoding="utf-8-sig")
print(f"\n✅ Listo: {CSV_OUT} ({len(df_out)} filas)")
display(df_out.head())
# Out:
# Inicio: 2025-09-21 02:06:34
# Total URLs: 1000 | Concurrency: 4 | Headless: True
#
# [1/1000] —  31.93s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7817876&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOdAAH&control=svs&pestania=3
# [2/1000] —  31.95s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=6375845&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAEXAAX&control=svs&pestania=3
# [3/1000] —  31.98s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=4888705&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAEIAAT&control=svs&pestania=3
# [4/1000] —  31.99s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=9623180&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWPzAAF&control=svs&pestania=3
# [5/1000] —  31.44s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=16582192&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOrAAf&control=svs&pestania=3
# [6/1000] —  31.55s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=8234597&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWO7AAk&control=svs&pestania=3
# [7/1000] —  31.53s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=13990606&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAH9AAT&control=svs&pestania=3
# [8/1000] —  31.55s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=11542708&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOpAAG&control=svs&pestania=3
# [9/1000] —  31.36s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=5137633&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAE5AAo&control=svs&pestania=3
# [10/1000] —  31.35s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7135377&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAHGAAK&control=svs&pestania=3
# [11/1000] —  31.60s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=13508600&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWPVAAC&control=svs&pestania=3
# [12/1000] —  31.62s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=14310447&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAW
grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAGNAAM&control=svs&pestania=3
#
# Fin batch: 1000 URLs en 16459.2s  (~0.06 urls/s)
#
# ✅ Listo: num_empleados_caratula_pn2.csv (1000 filas)
#                                                  URL N° de Empleados
# 0  https://www.cmfchile.cl/institucional/mercados...            None
# 1  https://www.cmfchile.cl/institucional/mercados...            None
# 2  https://www.cmfchile.cl/institucional/mercados...            None
# 3  https://www.cmfchile.cl/institucional/mercados...            None
# 4  https://www.cmfchile.cl/institucional/mercados...            None

# %% [markdown]
# <h2>3</h2>

# %%
# ====== Config ======
EXCEL_IN    = "detalle_pn3.xlsx"                # archivo con las URLs
COL_URL     = "URL Ficha"                       # nombre EXACTO de la columna con la URL
CSV_OUT     = "num_empleados_caratula_pn3.csv"  # salida
PERIODO     = "12"
ANIO        = "2024"
CONCURRENCY = 4                                  # páginas en paralelo
HEADLESS    = True                               # pon False si quieres ver el navegador

# ====== Código ======
import time, asyncio, nest_asyncio, pandas as pd
from datetime import datetime
from playwright.async_api import async_playwright

nest_asyncio.apply()

ROW_SELECTOR = "div#caratula table tr:has(td:has-text('1.15.00.00'))"
EMP_FALLBACK = "div#caratula table tr:has(td:has-text('Empleados'))"

async def setup_browser(headless=HEADLESS):
    p = await async_playwright().start()
    browser = await p.chromium.launch(headless=headless)
    ctx = await browser.new_context(
        locale="es-CL",
        user_agent=("Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 "
                    "(KHTML, like Gecko) Chrome/120 Safari/537.36"),
    )
    # bloquear recursos pesados
    await ctx.route("**/*", lambda route, request: (
        route.abort()
        if request.resource_type in {"image", "stylesheet", "font", "media"}
        else route.continue_()
    ))
    return p, browser, ctx

async def scrape_url(ctx, url, periodo=PERIODO, anio=ANIO, timeout_ms=30000):
    """Devuelve {'URL': url, 'N° de Empleados': valor}"""
    page = await ctx.new_page()
    page.set_default_timeout(timeout_ms)
    try:
        await page.goto(url, wait_until="domcontentloaded")

        # setear selects + Consultar (si existen)
        try:
            form = page.locator("form").first
            selects = form.locator("select")
            if await selects.count() >= 1:
                await selects.nth(0).select_option(value=str(periodo))
            if await selects.count() >= 2:
                try:
                    await selects.nth(1).select_option(value=str(anio))
                except:
                    await selects.nth(1).select_option(label=str(anio))
            # click consultar
            try:
                await form.get_by_role("button", name="Consultar").click()
            except:
                try:
                    await page.locator("button:has-text('Consultar')").click()
                except:
                    await page.locator("input[type=submit]").first.click()
        except Exception:
            pass

        # esperar directamente la fila (o la tabla si no aparece)
        row = page.locator(ROW_SELECTOR).first
        try:
            await row.wait_for(state="visible", timeout=15000)
        except:
            await page.wait_for_selector("div#caratula table", timeout=15000)
            row = page.locator(EMP_FALLBACK).first

        # extraer último <td> de la fila
        valor = None
        if await row.count() > 0:
            tds = row.locator("td")
            n = await tds.count()
            if n > 0:
                valor = (await tds.nth(n-1).inner_text()).strip()

        return {"URL": url, "N° de Empleados": valor}
    except Exception:
        return {"URL": url, "N° de Empleados": None}
    finally:
        try:
            await page.close()
        except:
            pass

async def run_batch(urls, concurrency=CONCURRENCY):
    p, browser, ctx = await setup_browser()
    sem = asyncio.Semaphore(concurrency)

    total = len(urls)
    done = 0
    start_ts = time.time()
    results = []

    async def worker(u, idx):
        nonlocal done
        async with sem:
            t0 = time.time()
            res = await scrape_url(ctx, u)
            elapsed = time.time() - t0
            done += 1

            # imprimir progreso (flush inmediato)
            estado = "OK" if res.get("N° de Empleados") not in (None, "") else "—"
            print(f"[{done}/{total}] {estado}  {elapsed:5.2f}s  -> {u}", flush=True)

            results.append(res)

    try:
        tasks = [asyncio.create_task(worker(u, i)) for i, u in enumerate(urls)]
        # ir mostrando progreso a medida que terminan
        for fut in asyncio.as_completed(tasks):
            await fut

        total_elapsed = time.time() - start_ts
        print(f"\nFin batch: {total} URLs en {total_elapsed:0.1f}s  (~{total/total_elapsed:0.2f} urls/s)", flush=True)
    finally:
        try:  await ctx.close()
        except: pass
        try:  await browser.close()
        except: pass
        try:  await p.stop()
        except: pass
    return results

# ====== Leer Excel, ejecutar y guardar ======
df_in = pd.read_excel(EXCEL_IN)
if COL_URL not in df_in.columns:
    raise ValueError(f"No encontré la columna '{COL_URL}' en {EXCEL_IN}")

urls = df_in[COL_URL].dropna().astype(str).tolist()

print(f"Inicio: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"Total URLs: {len(urls)} | Concurrency: {CONCURRENCY} | Headless: {HEADLESS}\n")

results = await run_batch(urls)

df_out = pd.DataFrame(results)
df_out.to_csv(CSV_OUT, index=False, encoding="utf-8-sig")
print(f"\n✅ Listo: {CSV_OUT} ({len(df_out)} filas)")
display(df_out.head())
# Out:
# Inicio: 2025-09-21 06:44:20
# Total URLs: 999 | Concurrency: 4 | Headless: True
#
# [1/999] —  32.02s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=3518542&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAFMAAG&control=svs&pestania=3
# [2/999] —  32.05s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7196897&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAHVAAQ&control=svs&pestania=3
# [3/999] —  32.08s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=8914567&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWO3AAR&control=svs&pestania=3
# [4/999] —  32.68s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=10322112&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOnAAi&control=svs&pestania=3
# [5/999] —  31.14s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=3916152&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAEdAAO&control=svs&pestania=3
# [6/999] —  31.18s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=15924490&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOMAAV&control=svs&pestania=3
# [7/999] —  31.25s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=6713574&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAFgAAZ&control=svs&pestania=3
# [8/999] —  31.36s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=9156060&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAFRAAf&control=svs&pestania=3
# [9/999] —  31.19s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=9876405&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWO4AAg&control=svs&pestania=3
# [10/999] —  31.28s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=8831100&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAFqAAK&control=svs&pestania=3
# [11/999] —  31.45s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=6600580&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAE3AAb&control=svs&pestania=3
# [12/999] —  31.44s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=4337638&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAFBAAN&control=svs&pestania=3
# [13/999] —  31.14s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=10455070&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAHOAAM&control=svs&pestania=3
# [14/999] —  31.39s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=6408614&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAHMAAJ&control=svs&pestania=3
# [15/999] —  31.55s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=19690234&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWPgAAB&control=svs&pestania=3
# [16/999] —  31.40s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=5312309&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAEMAAC&control=svs&pestania=3
# [17/999] —  30.90s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=5572334&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAEuAAB&control=svs&pestania=3
# [18/999] —  30.93s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=8526150&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAAH4AAc&control=svs&pestania=3
# [19/999] —  31.16s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=19332503&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWPIAAH&control=svs&pestania=3
# [20/999] —  31.08s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7025993&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWPIAAJ&control=svs&pestania=3
# [21/999] —  30.75s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=11874030&grupo=&tipoentidad=CSNAT&vig=VI&row=AAAwU3AAWAAAWOzAAI&control=svs&pestania=3
# [22/999] —  30.92s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=
grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAGCAAa&control=svs&pestania=3
# [67/999] —  30.66s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=8085831&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAWORAAL&control=svs&pestania=3
# [68/999] —  30.67s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7526505&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAWPKAAD&control=svs&pestania=3
# [69/999] —  30.57s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=6685729&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAFQAAV&control=svs&pestania=3
# [70/999] —  30.56s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=8991369&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAGUAAB&control=svs&pestania=3
# [71/999] —  30.67s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=4889860&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAF8AAN&control=svs&pestania=3
# [72/999] —  30.70s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=5492499&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAEHAAt&control=svs&pestania=3
# [73/999] —  30.68s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=5492499&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAHTAAH&control=svs&pestania=3
# [74/999] —  30.68s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=2274997&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAEjAAd&control=svs&pestania=3
# [75/999] —  30.71s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=6916424&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAF0AAE&control=svs&pestania=3
# [76/999] —  30.72s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=9428379&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAGQAAX&control=svs&pestania=3
# [77/999] —  30.68s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=12867281&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAHVAAB&control=svs&pestania=3
# [78/999] —  30.70s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=8148067&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAFCAAO&control=svs&pestania=3
# [79/999] —  30.70s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=16672609&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAWO4AAC&control=svs&pestania=3
# [80/999] —  30.70s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=13525420&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAWPkAAD&control=svs&pestania=3
# [81/999] —  30.71s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=4488681&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAEXAAf&control=svs&pestania=3
# [82/999] —  30.69s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7972057&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAFiAAH&control=svs&pestania=3
# [83/999] —  30.65s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=4673876&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAGKAAb&control=svs&pestania=3
# [84/999] —  30.82s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=5612841&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAEWAAE&control=svs&pestania=3
# [85/999] —  54.66s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=2232627&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAEiAAm&control=svs&pestania=3
# [86/999] —  53.86s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=8537454&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAHpAAO&control=svs&pestania=3
# [87/999] —  52.95s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=5528167&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAENAAQ&control=svs&pestania=3
# [88/999] —  51.96s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=8623110&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAFXAAV&control=svs&pestania=3
# [89/999] —  1828.13s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=9598019&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAFbAAs&control=svs&pestania=3
# [90/999] —  1828.14s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7927411&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAFxAAR&control=svs&pestania=3
# [91/999] —  1828.09s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=4584333&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAEgAAn&control=svs&pestania=3
# [92/999] —  1828.14s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7927411&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAWOCAAB&control=svs&pestania=3
# [93/999] —  31.26s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7991281&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAFiAAc&control=svs&pestania=3
# [94/999] —  31.26s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=11614154&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAWORAAN&control=svs&pestania=3
# [95/999] —  31.37s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=4042335&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAEyAAm&control=svs&pestania=3
# [96/999] —  31.65s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=4915357&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAEVAAL&control=svs&pestania=3
# [97/999] —  31.12s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=4016438&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAEtAAm&control=svs&pestania=3
# [98/999] —  31.19s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=5765415&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAExAAH&control=svs&pestania=3
# [99/999] —  31.48s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=3729511&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAE%2FAAq&control=svs&pestania=3
# [100/999] —  31.28s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=5177234&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAE6AAr&control=svs&pestania=3
# [101/999] —  30.77s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=8153017&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAFCAAS&control=svs&pestania=3
# [102/999] —  31.00s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=13252623&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAWOlAAD&control=svs&pestania=3
# [103/999] —  31.09s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7193613&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAGkAAC&control=svs&pestania=3
# [104/999] —  31.04s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=8150348&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAFCAAR&control=svs&pestania=3
# [105/999] —  30.68s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=6359609&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAESAAF&control=svs&pestania=3
# [106/999] —  30.87s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=2188031&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAEiAAU&control=svs&pestania=3
# [107/999] —  30.85s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=4458575&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAESAAX&control=svs&pestania=3
# [108/999] —  30.86s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=6489269&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAEcAAK&control=svs&pestania=3
# [109/999] —  30.64s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=5440772&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAF8AAf&control=svs&pestania=3
# [110/999] —  30.84s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=10384075&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAHSAAe&control=svs&pestania=3
# [111/999] —  31.04s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=9060825&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAWPsAAB&control=svs&pestania=3
# [112/999] —  31.07s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7166022&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAFNAAF&control=svs&pestania=3
# [113/999] —  30.60s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=
  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=8114642&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAHqAAF&control=svs&pestania=3
# [981/999] —  30.70s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=18210523&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAHVAAe&control=svs&pestania=3
# [982/999] —  30.70s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7021537&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAF0AAZ&control=svs&pestania=3
# [983/999] —  30.66s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=2799465&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAEmAAe&control=svs&pestania=3
# [984/999] —  30.76s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=18321900&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAWOVAAB&control=svs&pestania=3
# [985/999] —  30.73s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=18321900&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAWOsAAF&control=svs&pestania=3
# [986/999] —  30.65s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=18321900&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAWO+AAf&control=svs&pestania=3
# [987/999] —  30.83s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=8891193&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAGkAAP&control=svs&pestania=3
# [988/999] —  30.70s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7840887&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAFgAAl&control=svs&pestania=3
# [989/999] —  30.73s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=12289678&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAWOLAAX&control=svs&pestania=3
# [990/999] —  30.67s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=6416544&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAFgAAP&control=svs&pestania=3
# [991/999] —  30.69s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=12847017&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAGnAAT&control=svs&pestania=3
# [992/999] —  30.70s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=2429760&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAFBAAB&control=svs&pestania=3
# [993/999] —  30.79s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=4898298&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAEIAAY&control=svs&pestania=3
# [994/999] —  30.67s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=6823049&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAHdAAe&control=svs&pestania=3
# [995/999] —  30.68s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7201641&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAGkAAK&control=svs&pestania=3
# [996/999] —  30.66s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=12628199&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAHSAAQ&control=svs&pestania=3
# [997/999] —  30.73s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=7033765&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAFqAAs&control=svs&pestania=3
# [998/999] —  30.70s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=16494552&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAWOoAAI&control=svs&pestania=3
# [999/999] —  30.67s  -> https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=5745235&grupo=&tipoentidad=CSNAT&vig=NV&row=AAAwU3AAWAAAAEhAAG&control=svs&pestania=3
#
# Fin batch: 999 URLs en 12186.3s  (~0.08 urls/s)
#
# ✅ Listo: num_empleados_caratula_pn3.csv (999 filas)
#                                                  URL N° de Empleados
# 0  https://www.cmfchile.cl/institucional/mercados...            None
# 1  https://www.cmfchile.cl/institucional/mercados...            None
# 2  https://www.cmfchile.cl/institucional/mercados...            None
# 3  https://www.cmfchile.cl/institucional/mercados...            None
# 4  https://www.cmfchile.cl/institucional/mercados...            None

# %% [markdown]
# <h2>4</h2>

# %%
# ====== Config ======
EXCEL_IN    = "detalle_pn4.xlsx"                # archivo con las URLs
COL_URL     = "URL Ficha"                       # nombre EXACTO de la columna con la URL
CSV_OUT     = "num_empleados_caratula_pn4.csv"  # salida
PERIODO     = "12"
ANIO        = "2024"
CONCURRENCY = 4                                  # páginas en paralelo
HEADLESS    = True                               # pon False si quieres ver el navegador

# ====== Código ======
import time, asyncio, nest_asyncio, pandas as pd
from datetime import datetime
from playwright.async_api import async_playwright

nest_asyncio.apply()

ROW_SELECTOR = "div#caratula table tr:has(td:has-text('1.15.00.00'))"
EMP_FALLBACK = "div#caratula table tr:has(td:has-text('Empleados'))"

async def setup_browser(headless=HEADLESS):
    p = await async_playwright().start()
    browser = await p.chromium.launch(headless=headless)
    ctx = await browser.new_context(
        locale="es-CL",
        user_agent=("Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 "
                    "(KHTML, like Gecko) Chrome/120 Safari/537.36"),
    )
    # bloquear recursos pesados
    await ctx.route("**/*", lambda route, request: (
        route.abort()
        if request.resource_type in {"image", "stylesheet", "font", "media"}
        else route.continue_()
    ))
    return p, browser, ctx

async def scrape_url(ctx, url, periodo=PERIODO, anio=ANIO, timeout_ms=30000):
    """Devuelve {'URL': url, 'N° de Empleados': valor}"""
    page = await ctx.new_page()
    page.set_default_timeout(timeout_ms)
    try:
        await page.goto(url, wait_until="domcontentloaded")

        # setear selects + Consultar (si existen)
        try:
            form = page.locator("form").first
            selects = form.locator("select")
            if await selects.count() >= 1:
                await selects.nth(0).select_option(value=str(periodo))
            if await selects.count() >= 2:
                try:
                    await selects.nth(1).select_option(value=str(anio))
                except:
                    await selects.nth(1).select_option(label=str(anio))
            # click consultar
            try:
                await form.get_by_role("button", name="Consultar").click()
            except:
                try:
                    await page.locator("button:has-text('Consultar')").click()
                except:
                    await page.locator("input[type=submit]").first.click()
        except Exception:
            pass

        # esperar directamente la fila (o la tabla si no aparece)
        row = page.locator(ROW_SELECTOR).first
        try:
            await row.wait_for(state="visible", timeout=15000)
        except:
            await page.wait_for_selector("div#caratula table", timeout=15000)
            row = page.locator(EMP_FALLBACK).first

        # extraer último <td> de la fila
        valor = None
        if await row.count() > 0:
            tds = row.locator("td")
            n = await tds.count()
            if n > 0:
                valor = (await tds.nth(n-1).inner_text()).strip()

        return {"URL": url, "N° de Empleados": valor}
    except Exception:
        return {"URL": url, "N° de Empleados": None}
    finally:
        try:
            await page.close()
        except:
            pass

async def run_batch(urls, concurrency=CONCURRENCY):
    p, browser, ctx = await setup_browser()
    sem = asyncio.Semaphore(concurrency)

    total = len(urls)
    done = 0
    start_ts = time.time()
    results = []

    async def worker(u, idx):
        nonlocal done
        async with sem:
            t0 = time.time()
            res = await scrape_url(ctx, u)
            elapsed = time.time() - t0
            done += 1

            # imprimir progreso (flush inmediato)
            estado = "OK" if res.get("N° de Empleados") not in (None, "") else "—"
            print(f"[{done}/{total}] {estado}  {elapsed:5.2f}s  -> {u}", flush=True)

            results.append(res)

    try:
        tasks = [asyncio.create_task(worker(u, i)) for i, u in enumerate(urls)]
        # ir mostrando progreso a medida que terminan
        for fut in asyncio.as_completed(tasks):
            await fut

        total_elapsed = time.time() - start_ts
        print(f"\nFin batch: {total} URLs en {total_elapsed:0.1f}s  (~{total/total_elapsed:0.2f} urls/s)", flush=True)
    finally:
        try:  await ctx.close()
        except: pass
        try:  await browser.close()
        except: pass
        try:  await p.stop()
        except: pass
    return results

# ====== Leer Excel, ejecutar y guardar ======
df_in = pd.read_excel(EXCEL_IN)
if COL_URL not in df_in.columns:
    raise ValueError(f"No encontré la columna '{COL_URL}' en {EXCEL_IN}")

urls = df_in[COL_URL].dropna().astype(str).tolist()

print(f"Inicio: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"Total URLs: {len(urls)} | Concurrency: {CONCURRENCY} | Headless: {HEADLESS}\n")

results = await run_batch(urls)

df_out = pd.DataFrame(results)a<<<cxzc<
print(f"\n✅ Listo: {CSV_OUT} ({len(df_out)} filas)")
display(df_out.head())
# Out:
#   Cell In[4], line 142
#     df_out = pd.DataFrame(results)a<<<cxzc<
#                                   ^
# SyntaxError: invalid syntax
