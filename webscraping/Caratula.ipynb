# %%
# === Config ===
URL = "https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76457592&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOaAAW&control=svs&pestania=3"
PERIODO = "12"
ANIO    = "2024"
HEADLESS = True

import re, nest_asyncio
from bs4 import BeautifulSoup
from IPython.display import HTML, display
from playwright.async_api import async_playwright

nest_asyncio.apply()

async def fetch_html(url: str, periodo=PERIODO, anio=ANIO, headless=HEADLESS) -> str:
    async with async_playwright() as p:
        br = await p.chromium.launch(headless=headless)
        ctx = await br.new_context(locale="es-CL")
        page = await ctx.new_page()
        page.set_default_timeout(45000)
        await page.goto(url, wait_until="domcontentloaded")

        # Periodo/Año + Consultar (si existen)
        try:
            form = page.locator("form").first
            sels = form.locator("select")
            if await sels.count() >= 1:
                await sels.nth(0).select_option(value=str(periodo))
            if await sels.count() >= 2:
                try:
                    await sels.nth(1).select_option(value=str(anio))
                except:
                    await sels.nth(1).select_option(label=str(anio))
            try:
                await form.get_by_role("button", name="Consultar").click()
            except:
                try:
                    await page.locator("button:has-text('Consultar')").click()
                except:
                    await page.locator("input[type=submit']").first.click()
        except Exception:
            pass

        # Espera a que la carátula exista y tenga filas
        await page.wait_for_selector("#caratula table", timeout=30000)
        await page.wait_for_function("document.querySelectorAll('#caratula table tr').length > 5", timeout=30000)

        html = await page.content()
        await br.close()
        return html

def extraer_num_empleados(html: str):
    soup = BeautifulSoup(html, "lxml")

    # Vamos directo a la carátula
    caratula = soup.select_one("div#caratula table")
    if not caratula:
        return None, None   # (fila_html, valor)

    # Recorremos las filas; primera celda debe ser 1.15.00.00
    for tr in caratula.find_all("tr"):
        tds = tr.find_all("td", recursive=True)
        if not tds:
            continue
        first = re.sub(r"\s+", " ", tds[0].get_text(" ", strip=True))
        if first == "1.15.00.00":
            # valor = último <td> (conservamos formato tal cual)
            valor = tds[-1].get_text(" ", strip=True)
            # para mostrar la fila tal cual:
            fila_html = f"<table style='border-collapse:collapse;font-family:system-ui'><tr>" + \
                        "".join(f"<td style='border:1px solid #ccc;padding:6px 8px'>{td.get_text(' ', strip=True)}</td>" for td in tds) + \
                        "</tr></table>"
            return fila_html, valor

    # Fallback: buscar por texto "N° de Empleados" y subir al <tr>
    nodo = caratula.find(string=re.compile(r"N[\u00B0º]?\s*de\s*Empleados", re.I))
    if nodo:
        tr = nodo.find_parent("tr")
        if tr:
            tds = tr.find_all("td", recursive=True)
            valor = tds[-1].get_text(" ", strip=True) if tds else None
            fila_html = f"<table style='border-collapse:collapse;font-family:system-ui'><tr>" + \
                        "".join(f"<td style='border:1px solid #ccc;padding:6px 8px'>{td.get_text(' ', strip=True)}</td>" for td in tds) + \
                        "</tr></table>"
            return fila_html, valor

    return None, None

# === Ejecutar para la URL de ejemplo ===
html = await fetch_html(URL)
fila_html, valor = extraer_num_empleados(html)

if fila_html:
    print("Fila encontrada (1.15.00.00):")
    display(HTML(fila_html))
    print("Valor N° de Empleados:", valor)
else:
    print("No se encontró la fila 1.15.00.00 en la Carátula.")
# Out:
# Fila encontrada (1.15.00.00):
# <table style='border-collapse:collapse;font-family:system-ui'><tr><td style='border:1px solid #ccc;padding:6px 8px'>1.15.00.00</td><td style='border:1px solid #ccc;padding:6px 8px'>N° de Empleados</td><td style='border:1px solid #ccc;padding:6px 8px'>6</td></tr></table>
# Valor N° de Empleados: 6

# %%
import pandas as pd

# Cargar archivo con tus URLs
df_urls = pd.read_excel("detalle_pj.xlsx")

resultados = []

for i, row in df_urls.iterrows():
    url = row["URL Ficha"]
    print(f"=== {i+1}/{len(df_urls)} ===")
    print("URL:", url)

    try:
        html = await fetch_html(url)
        fila_html, valor = extraer_num_empleados(html)
        resultados.append({
            "RUT": row.get("RUT"), 
            "Entidad": row.get("Entidad"),
            "URL": url,
            "N° Empleados": valor
        })
    except Exception as e:
        print("❌ Error en", url, ":", e)
        resultados.append({
            "RUT": row.get("RUT"),
            "Entidad": row.get("Entidad"),
            "URL": url,
            "N° Empleados": None
        })

# Convertir a DataFrame final
df_res = pd.DataFrame(resultados)
display(df_res.head())
# Out:
# === 1/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76457592&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOaAAW&control=svs&pestania=3
# === 2/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76457592&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOaAAW&control=svs&pestania=3
# === 3/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76457592&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOaAAW&control=svs&pestania=3
# Task exception was never retrieved
# future: <Task finished name='Task-241' coro=<Connection.run.<locals>.init() done, defined at /opt/anaconda3/lib/python3.11/site-packages/playwright/_impl/_connection.py:307> exception=Exception('Connection.init: Connection closed while reading from the driver')>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/asyncio/tasks.py", line 277, in __step
#     result = coro.send(None)
#              ^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/playwright/_impl/_connection.py", line 308, in init
#     self.playwright_future.set_result(await self._root_object.initialize())
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/playwright/_impl/_connection.py", line 249, in initialize
#     await self._channel.send(
#   File "/opt/anaconda3/lib/python3.11/site-packages/playwright/_impl/_connection.py", line 69, in send
#     return await self._connection.wrap_api_call(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/playwright/_impl/_connection.py", line 558, in wrap_api_call
#     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
# Exception: Connection.init: Connection closed while reading from the driver
# ❌ Error en https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76457592&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOaAAW&control=svs&pestania=3 : Page.wait_for_selector: Target page, context or browser has been closed
# === 4/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76457592&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOaAAW&control=svs&pestania=3
# ❌ Error en https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76457592&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOaAAW&control=svs&pestania=3 : Connection closed while reading from the driver
# === 5/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77672889&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOgAAf&control=svs&pestania=3
# ❌ Error en https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77672889&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOgAAf&control=svs&pestania=3 : Page.wait_for_selector: Timeout 30000ms exceeded.
# Call log:
#   - waiting for locator("#caratula table") to be visible
#     64 × locator resolved to hidden <table border="1" id="tabla_c">↵⇆⇆   ↵⇆</table>
#
# === 6/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76815712&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWO%2FAAJ&control=svs&pestania=3
# === 7/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=78082726&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWPnAAI&control=svs&pestania=3
# ❌ Error en https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=78082726&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWPnAAI&control=svs&pestania=3 : Page.wait_for_selector: Timeout 30000ms exceeded.
# Call log:
#   - waiting for locator("#caratula table") to be visible
#     64 × locator resolved to hidden <table border="1" id="tabla_c">↵⇆⇆   ↵⇆</table>
#
# === 8/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=78159157&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWPcAAK&control=svs&pestania=3
# ❌ Error en https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=78159157&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWPcAAK&control=svs&pestania=3 : Page.wait_for_selector: Target page, context or browser has been closed
# Call log:
#   - waiting for locator("#caratula table") to be visible
#     31 × locator resolved to hidden <table border="1" id="tabla_c">↵⇆⇆   ↵⇆</table>
#
# === 9/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76026159&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAHaAAR&control=svs&pestania=3
# === 10/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76204605&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAHgAAP&control=svs&pestania=3
# ❌ Error en https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76204605&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAHgAAP&control=svs&pestania=3 : Page.goto: net::ERR_ABORTED at https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76204605&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAHgAAP&control=svs&pestania=3
# Call log:
#   - navigating to "https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76204605&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAHgAAP&control=svs&pestania=3", waiting until "domcontentloaded"
#
# === 11/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76153122&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAHrAAL&control=svs&pestania=3
# === 12/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76406444&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAH9AAI&control=svs&pestania=3
# ❌ Error en https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76406444&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAH9AAI&control=svs&pestania=3 : Page.wait_for_selector: Connection closed while reading from the driver
# === 13/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76226644&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAH2AAT&control=svs&pestania=3
# === 14/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77561270&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWO8AAD&control=svs&pestania=3

# %%
# --- CELDA 2 (script completo desde cero) ---
# Configuración
EXCEL_IN   = "detalle_pj.xlsx"               # archivo de entrada con las URLs
COL_URL    = "URL Ficha"                     # nombre EXACTO de la columna con la URL
CSV_OUT    = "num_empleados_caratula.csv"    # archivo de salida
PERIODO    = "12"                            # selector "Período"
ANIO       = "2024"                          # selector "Año"
HEADLESS   = True                            # poner False para ver el navegador
PAUSA_S    = 0.4                             # pausa entre requests (respeto al sitio)

# ---- Imports y setup ----
import re, time, pandas as pd, nest_asyncio, asyncio
from bs4 import BeautifulSoup
from playwright.async_api import async_playwright, TimeoutError as PWTimeout

nest_asyncio.apply()
pd.set_option("display.max_colwidth", None)

# ---- Navegación: abrir ficha (pestaña 3), setear período/año, apretar Consultar ----
async def fetch_html(url: str, periodo=PERIODO, anio=ANIO, headless=HEADLESS) -> str:
    browser = None
    context = None
    page = None
    try:
        async with async_playwright() as p:
            browser = await p.chromium.launch(headless=headless)
            context = await browser.new_context(locale="es-CL")
            page = await context.new_page()
            page.set_default_timeout(45000)

            await page.goto(url, wait_until="domcontentloaded")

            # Periodo/Año + "Consultar" (si existe el formulario)
            try:
                form = page.locator("form").first
                selects = form.locator("select")
                if await selects.count() >= 1:
                    await selects.nth(0).select_option(value=str(periodo))
                if await selects.count() >= 2:
                    try:
                        await selects.nth(1).select_option(value=str(anio))
                    except:
                        await selects.nth(1).select_option(label=str(anio))
                # Click en Consultar (probamos varias variantes)
                try:
                    await form.get_by_role("button", name="Consultar").click()
                except:
                    try:
                        await page.locator("button:has-text('Consultar')").click()
                    except:
                        await page.locator("input[type=submit]").first.click()
            except Exception:
                # Algunas fichas ya vienen con datos cargados; continuamos
                pass

            # Esperar a que exista la tabla de carátula y tenga filas
            try:
                await page.wait_for_selector("#caratula table", timeout=30000, state="visible")
                await page.wait_for_function(
                    "document.querySelectorAll('#caratula table tr').length > 5", timeout=30000
                )
            except PWTimeout:
                # Último recurso: esperar cualquier tabla visible
                await page.wait_for_selector("table", timeout=20000, state="visible")

            html = await page.content()
            return html
    finally:
        # Cierre ordenado (evita TargetClosedError colgantes)
        try:
            if page:    await page.close()
        except: pass
        try:
            if context: await context.close()
        except: pass
        try:
            if browser: await browser.close()
        except: pass

# ---- Parsing: extraer N° de Empleados desde div#caratula > table ----
def extraer_num_empleados(html: str):
    """
    Busca en div#caratula > table una fila cuyo primer <td> sea '1.15.00.00'
    y devuelve el valor del último <td>. Si no está, intenta por glosa 'N° de Empleados'.
    Retorna: (valor_str | None)
    """
    soup = BeautifulSoup(html, "lxml")
    tabla = soup.select_one("div#caratula table")
    if not tabla:
        return None

    # 1) exacto por código en la primera celda
    for tr in tabla.find_all("tr"):
        tds = tr.find_all("td", recursive=True)
        if not tds:
            continue
        first = re.sub(r"\s+", " ", tds[0].get_text(" ", strip=True))
        if first == "1.15.00.00":
            return tds[-1].get_text(" ", strip=True)  # conserva formato (ej: 6 o 10,00)

    # 2) fallback por glosa
    nodo = tabla.find(string=re.compile(r"N[\u00B0º]?\s*de\s*Empleados", re.I))
    if nodo:
        tr = nodo.find_parent("tr")
        if tr:
            tds = tr.find_all("td", recursive=True)
            if tds:
                return tds[-1].get_text(" ", strip=True)

    return None

# ---- Runner: recorre el Excel y guarda CSV ----
async def main_to_csv():
    # Leer Excel
    df_in = pd.read_excel(EXCEL_IN)
    if COL_URL not in df_in.columns:
        raise ValueError(f"No encontré la columna '{COL_URL}' en {EXCEL_IN}")

    resultados = []

    for i, row in df_in.iterrows():
        url = str(row[COL_URL]).strip() if pd.notna(row[COL_URL]) else ""
        if not url:
            continue

        print(f"\n=== {i+1}/{len(df_in)} ===")
        print("URL:", url)

        try:
            html = await fetch_html(url)
            valor = extraer_num_empleados(html)
            resultados.append({
                "URL": url,
                "N° de Empleados": valor
            })
            print("→ N° de Empleados:", valor)
        except Exception as e:
            print("❌ Error:", e)
            resultados.append({
                "URL": url,
                "N° de Empleados": None
            })

        time.sleep(PAUSA_S)  # pausa amable

    # Guardar CSV
    df_out = pd.DataFrame(resultados)
    df_out.to_csv(CSV_OUT, index=False, encoding="utf-8-sig")
    print(f"\n✅ CSV guardado: {CSV_OUT} (filas: {len(df_out)})")
    display(df_out.head())

# Ejecutar
await main_to_csv()
# Out:
# === 1/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76457592&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOaAAW&control=svs&pestania=3
# → N° de Empleados: 6
#
# === 2/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76457592&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOaAAW&control=svs&pestania=3
# → N° de Empleados: 6
#
# === 3/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76457592&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOaAAW&control=svs&pestania=3
# → N° de Empleados: 6
#
# === 4/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76457592&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOaAAW&control=svs&pestania=3
# → N° de Empleados: 6
#
# === 5/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77672889&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOgAAf&control=svs&pestania=3
# ❌ Error: Page.wait_for_selector: Timeout 20000ms exceeded.
# Call log:
#   - waiting for locator("table") to be visible
#     45 × locator resolved to 16 elements. Proceeding with the first one: <table border="1" width="60%" id="tabla_c">↵⇆⇆   ↵⇆</table>
#
#
# === 6/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76815712&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWO%2FAAJ&control=svs&pestania=3
# → N° de Empleados: 6
#
# === 7/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=78082726&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWPnAAI&control=svs&pestania=3
# ❌ Error: Page.wait_for_selector: Timeout 20000ms exceeded.
# Call log:
#   - waiting for locator("table") to be visible
#     45 × locator resolved to 16 elements. Proceeding with the first one: <table border="1" width="60%" id="tabla_c">↵⇆⇆   ↵⇆</table>
#
#
# === 8/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=78159157&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWPcAAK&control=svs&pestania=3
# ❌ Error: Page.wait_for_selector: Timeout 20000ms exceeded.
# Call log:
#   - waiting for locator("table") to be visible
#     45 × locator resolved to 16 elements. Proceeding with the first one: <table border="1" width="60%" id="tabla_c">↵⇆⇆   ↵⇆</table>
#
#
# === 9/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76026159&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAHaAAR&control=svs&pestania=3
# → N° de Empleados: 2
#
# === 10/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76204605&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAHgAAP&control=svs&pestania=3
# → N° de Empleados: 3
#
# === 11/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76153122&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAHrAAL&control=svs&pestania=3
# → N° de Empleados: 0
#
# === 12/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76406444&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAH9AAI&control=svs&pestania=3
# → N° de Empleados: 1
#
# === 13/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76226644&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAH2AAT&control=svs&pestania=3
# → N° de Empleados: 2
#
# === 14/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77561270&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWO8AAD&control=svs&pestania=3
# ❌ Error: Page.wait_for_selector: Timeout 20000ms exceeded.
# Call log:
#   - waiting for locator("table") to be visible
#     45 × locator resolved to 17 elements. Proceeding with the first one: <table border="1" width="60%" id="tabla_c">↵⇆⇆   ↵⇆</table>
#
#
# === 15/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77830800&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOdAAB&control=svs&pestania=3
# ❌ Error: Page.wait_for_selector: Timeout 20000ms exceeded.
# Call log:
#   - waiting for locator("table") to be visible
#     45 × locator resolved to 16 elements. Proceeding with the first one: <table border="1" width="60%" id="tabla_c">↵⇆⇆   ↵⇆</table>
#
#
# === 16/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77094262&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWO+AAN&control=svs&pestania=3
# → N° de Empleados: 0
#
# === 17/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=78022109&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWPaAAN&control=svs&pestania=3
# ❌ Error: Page.wait_for_selector: Timeout 20000ms exceeded.
# Call log:
#   - waiting for locator("table") to be visible
#     45 × locator resolved to 16 elements. Proceeding with the first one: <table border="1" width="60%" id="tabla_c">↵⇆⇆   ↵⇆</table>
#
#
# === 18/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76551724&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOJAAY&control=svs&pestania=3
# → N° de Empleados: 0
#
# === 19/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76351294&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWODAAR&control=svs&pestania=3
# → N° de Empleados: 1
#
# === 20/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76245107&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAH1AAY&control=svs&pestania=3
# → N° de Empleados: 0
#
# === 21/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76993080&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOeAAE&control=svs&pestania=3
# → N° de Empleados: 3
#
# === 22/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76049617&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAHhAAa&control=svs&pestania=3
# → N° de Empleados: 0
#
# === 23/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77958984&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWPqAAH&control=svs&pestania=3
# → N° de Empleados: 2
#
# === 24/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77266187&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWO6AAT&control=svs&pestania=3
# → N° de Empleados: 1
#
# === 25/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77580055&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOhAAY&control=svs&pestania=3
# ❌ Error: Page.wait_for_selector: Timeout 20000ms exceeded.
# Call log:
#   - waiting for locator("table") to be visible
#     45 × locator resolved to 17 elements. Proceeding with the first one: <table border="1" width="60%" id="tabla_c">↵⇆⇆   ↵⇆</table>
#
#
# === 26/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77119684&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOlAAK&control=svs&pestania=3
# → N° de Empleados: 5
#
# === 27/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76792953&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOrAAJ&control=svs&pestania=3
# → N° de Empleados: -
#
# === 28/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=88472100&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAGiAAZ&control=svs&pestania=3
# → N° de Empleados: 2
#
# === 29/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76696637&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOGAAN&control=svs&pestania=3
# → N° de Empleados: 0
#
# === 30/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77395963&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWO4AAZ&control=svs&pestania=3
# → N° de Empleados: 1
#
# === 31/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77494227&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOrAAb&control=svs&pestania=3
# → N° de Empleados: 0
#
# === 32/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76539827&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOUAAG&control=svs&pestania=3
# → N° de Empleados: 8
#
# === 33/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76882448&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWO%2FAAI&control=svs&pestania=3
# → N° de Empleados: 2
#
# === 34/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77522382&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWO3AAa&control=svs&pestania=3
# → N° de Empleados: 0
#
# === 35/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76122573&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWPPAAB&control=svs&pestania=3
# → N° de Empleados: 3
#
# === 36/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76946510&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAHnAAc&control=svs&pestania=3
# → N° de Empleados: 5
#
# === 37/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=78017894&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWPDAAC&control=svs&pestania=3
# ❌ Error: Page.wait_for_selector: Timeout 20000ms exceeded.
# Call log:
#   - waiting for locator("table") to be visible
#     45 × locator resolved to 16 elements. Proceeding with the first one: <table border="1" width="60%" id="tabla_c">↵⇆⇆   ↵⇆</table>
#
#
# === 38/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76079087&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAHmAAX&control=svs&pestania=3
# → N° de Empleados: 2
#
# === 39/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76805834&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOtAAK&control=svs&pestania=3
# → N° de Empleados: 6
#
# === 40/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76836850&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAHoAAD&control=svs&pestania=3
# → N° de Empleados: 1
#
# === 41/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76730413&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWO%2FAAB&control=svs&pestania=3
# → N° de Empleados: 1
#
# === 42/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76501820&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAHeAAI&control=svs&pestania=3
# ❌ Error: Page.wait_for_selector: Timeout 20000ms exceeded.
# Call log:
#   - waiting for locator("table") to be visible
#     44 × locator resolved to 16 elements. Proceeding with the first one: <table border="1" width="60%" id="tabla_c">↵⇆⇆   ↵⇆</table>
#
#
# === 43/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76226070&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAGmAAK&control=svs&pestania=3
# → N° de Empleados: 6
#
# === 44/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76346604&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAH1AAD&control=svs&pestania=3
# → N° de Empleados: 2
#
# === 45/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77324666&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOmAAV&control=svs&pestania=3
# → N° de Empleados: 3
#
# === 46/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77904918&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWPtAAI&control=svs&pestania=3
# → N° de Empleados: 1
#
# === 47/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77902495&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWPdAAG&control=svs&pestania=3
# ❌ Error: Page.wait_for_selector: Timeout 20000ms exceeded.
# Call log:
#   - waiting for locator("table") to be visible
#     45 × locator resolved to 16 elements. Proceeding with the first one: <table border="1" width="60%" id="tabla_c">↵⇆⇆   ↵⇆</table>
#
#
# === 48/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76268685&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAH6AAF&control=svs&pestania=3
# → N° de Empleados: 0
#
# === 49/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76183135&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAHvAAL&control=svs&pestania=3
# → N° de Empleados: 8
#
# === 50/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76567835&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOGAAe&control=svs&pestania=3
# → N° de Empleados: -
#
# === 51/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76039509&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAHTAAE&control=svs&pestania=3
# → N° de Empleados: 12
#
# === 52/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76608227&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOxAAB&control=svs&pestania=3
# → N° de Empleados: 1
#
# === 53/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77549305&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWP1AAB&control=svs&pestania=3
# → N° de Empleados: 1
#
# === 54/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76426288&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAH9AAL&control=svs&pestania=3
# → N° de Empleados: 2
#
# === 55/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76769441&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWO0AAA&control=svs&pestania=3
# → N° de Empleados: 2
#
# === 56/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76766107&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOpAAB&control=svs&pestania=3
# → N° de Empleados: 3
#
# === 57/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77082700&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAF7AAp&control=svs&pestania=3
# → N° de Empleados: 1
#
# === 58/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77967411&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWPpAAJ&control=svs&pestania=3
# ❌ Error: Page.wait_for_selector: Timeout 20000ms exceeded.
# Call log:
#   - waiting for locator("table") to be visible
#     45 × locator resolved to 16 elements. Proceeding with the first one: <table border="1" width="60%" id="tabla_c">↵⇆⇆   ↵⇆</table>
#
#
# === 59/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77568823&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOiAAh&control=svs&pestania=3
# → N° de Empleados: 7
#
# === 60/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77683179&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOjAAh&control=svs&pestania=3
# → N° de Empleados: 1
#
# === 61/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76316888&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAH8AAH&control=svs&pestania=3
# → N° de Empleados: 4
#
# === 62/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77750410&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAGWAAF&control=svs&pestania=3
# → N° de Empleados: 21
#
# === 63/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76010766&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAHNAAa&control=svs&pestania=3
# → N° de Empleados: 3
#
# === 64/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76131099&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAH0AAX&control=svs&pestania=3
# → N° de Empleados: 1
#
# === 65/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=93783000&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAFoAAh&control=svs&pestania=3
# → N° de Empleados: 229
#
# === 66/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=85541200&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAF2AAj&control=svs&pestania=3
# → N° de Empleados: 3
#
# === 67/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=79847830&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAFnAAm&control=svs&pestania=3
# ❌ Error: Page.wait_for_selector: Timeout 20000ms exceeded.
# Call log:
#   - waiting for locator("table") to be visible
#     45 × locator resolved to 16 elements. Proceeding with the first one: <table border="1" width="60%" id="tabla_c">↵⇆⇆   ↵⇆</table>
#
#
# === 68/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=78031335&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWP2AAH&control=svs&pestania=3
# ❌ Error: Page.wait_for_selector: Timeout 20000ms exceeded.
# Call log:
#   - waiting for locator("table") to be visible
#     45 × locator resolved to 16 elements. Proceeding with the first one: <table border="1" width="60%" id="tabla_c">↵⇆⇆   ↵⇆</table>
#
#
# === 69/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77374949&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOuAAd&control=svs&pestania=3
# → N° de Empleados: 1
#
# === 70/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77682370&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAHlAAb&control=svs&pestania=3
# → N° de Empleados: 472
#
# === 71/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76403883&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWPKAAI&control=svs&pestania=3
# → N° de Empleados: -
#
# === 72/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76197118&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAHuAAK&control=svs&pestania=3
# → N° de Empleados: 1
#
# === 73/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76731871&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOXAAH&control=svs&pestania=3
# → N° de Empleados: 0
#
# === 74/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=89437600&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAF9AAS&control=svs&pestania=3
# → N° de Empleados: -
#
# === 75/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=79770880&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAFnAAW&control=svs&pestania=3
# → N° de Empleados: 5
#
# === 76/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76203429&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAHbAAJ&control=svs&pestania=3
# → N° de Empleados: 8
#
# === 77/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=78150960&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWO9AAM&control=svs&pestania=3
# → N° de Empleados: 5
#
# === 78/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77658040&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAGHAAV&control=svs&pestania=3
# → N° de Empleados: 1
#
# === 79/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=78149580&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAGDAAF&control=svs&pestania=3
# → N° de Empleados: 4
#
# === 80/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77251559&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWO3AAe&control=svs&pestania=3
# → N° de Empleados: 0
#
# === 81/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=78462030&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAFCAAd&control=svs&pestania=3
# → N° de Empleados: 2
#
# === 82/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77027082&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOcAAY&control=svs&pestania=3
# → N° de Empleados: 3
#
# === 83/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76284223&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOgAAc&control=svs&pestania=3
# → N° de Empleados: 1
#
# === 84/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77965550&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAHjAAS&control=svs&pestania=3
# → N° de Empleados: 4
#
# === 85/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76070930&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAG2AAB&control=svs&pestania=3
# → N° de Empleados: 4
#
# === 86/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77638460&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAHeAAM&control=svs&pestania=3
# → N° de Empleados: 1
#
# === 87/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76284648&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOlAAN&control=svs&pestania=3
# ❌ Error: Page.wait_for_selector: Timeout 20000ms exceeded.
# Call log:
#   - waiting for locator("table") to be visible
#     45 × locator resolved to 16 elements. Proceeding with the first one: <table border="1" width="60%" id="tabla_c">↵⇆⇆   ↵⇆</table>
#
#
# === 88/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77035842&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWOzAAR&control=svs&pestania=3
# → N° de Empleados: -
#
# === 89/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=79945890&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAG%2FAAX&control=svs&pestania=3
# → N° de Empleados: 4
#
# === 90/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=76033280&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAAGZAAc&control=svs&pestania=3
# → N° de Empleados: 2
#
# === 91/1979 ===
# URL: https://www.cmfchile.cl/institucional/mercados/entidad.php?auth=&send=&mercado=S&rut=77831744&grupo=&tipoentidad=CSJUR&vig=VI&row=AAAwU3AAWAAAWPyAAD&control=svs&pestania=3
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[1], line 153
#     150     display(df_out.head())
#     152 # Ejecutar
# --> 153 await main_to_csv()
#
# Cell In[1], line 130, in main_to_csv()
#     127 print("URL:", url)
#     129 try:
# --> 130     html = await fetch_html(url)
#     131     valor = extraer_num_empleados(html)
#     132     resultados.append({
#     133         "URL": url,
#     134         "N° de Empleados": valor
#     135     })
#
# Cell In[1], line 58, in fetch_html(url, periodo, anio, headless)
#      56 # Esperar a que exista la tabla de carátula y tenga filas
#      57 try:
# ---> 58     await page.wait_for_selector("#caratula table", timeout=30000, state="visible")
#      59     await page.wait_for_function(
#      60         "document.querySelectorAll('#caratula table tr').length > 5", timeout=30000
#      61     )
#      62 except PWTimeout:
#      63     # Último recurso: esperar cualquier tabla visible
#
# File /opt/anaconda3/lib/python3.11/site-packages/playwright/async_api/_generated.py:8181, in Page.wait_for_selector(self, selector, timeout, state, strict)
#    8110 async def wait_for_selector(
#    8111     self,
#    8112     selector: str,
#    (...)
#    8118     strict: typing.Optional[bool] = None,
#    8119 ) -> typing.Optional["ElementHandle"]:
#    8120     """Page.wait_for_selector
#    8121
#    8122     Returns when element specified by selector satisfies `state` option. Returns `null` if waiting for `hidden` or
#    (...)
#    8177     Union[ElementHandle, None]
#    8178     """
#    8180     return mapping.from_impl_nullable(
# -> 8181         await self._impl_obj.wait_for_selector(
#    8182             selector=selector, timeout=timeout, state=state, strict=strict
#    8183         )
#    8184     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/playwright/_impl/_page.py:423, in Page.wait_for_selector(self, selector, timeout, state, strict)
#     416 async def wait_for_selector(
#     417     self,
#     418     selector: str,
#    (...)
#     421     strict: bool = None,
#     422 ) -> Optional[ElementHandle]:
# --> 423     return await self._main_frame.wait_for_selector(**locals_to_params(locals()))
#
# File /opt/anaconda3/lib/python3.11/site-packages/playwright/_impl/_frame.py:369, in Frame.wait_for_selector(self, selector, strict, timeout, state)
#     361 async def wait_for_selector(
#     362     self,
#     363     selector: str,
#    (...)
#     366     state: Literal["attached", "detached", "hidden", "visible"] = None,
#     367 ) -> Optional[ElementHandle]:
#     368     return from_nullable_channel(
# --> 369         await self._channel.send(
#     370             "waitForSelector", self._timeout, locals_to_params(locals())
#     371         )
#     372     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/playwright/_impl/_connection.py:69, in Channel.send(self, method, timeout_calculator, params, is_internal, title)
#      61 async def send(
#      62     self,
#      63     method: str,
#    (...)
#      67     title: str = None,
#      68 ) -> Any:
# ---> 69     return await self._connection.wrap_api_call(
#      70         lambda: self._inner_send(method, timeout_calculator, params, False),
#      71         is_internal,
#      72         title,
#      73     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/playwright/_impl/_connection.py:556, in Connection.wrap_api_call(self, cb, is_internal, title)
#     554 self._api_zone.set(parsed_st)
#     555 try:
# --> 556     return await cb()
#     557 except Exception as error:
#     558     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#
# File /opt/anaconda3/lib/python3.11/site-packages/playwright/_impl/_connection.py:123, in Channel._inner_send(self, method, timeout_calculator, params, return_as_dict)
#     119     raise error
#     120 callback = self._connection._send_message_to_server(
#     121     self._object, method, _augment_params(params, timeout_calculator)
#     122 )
# --> 123 done, _ = await asyncio.wait(
#     124     {
#     125         self._connection._transport.on_error_future,
#     126         callback.future,
#     127     },
#     128     return_when=asyncio.FIRST_COMPLETED,
#     129 )
#     130 if not callback.future.done():
#     131     callback.future.cancel()
#
# File /opt/anaconda3/lib/python3.11/asyncio/tasks.py:428, in wait(fs, timeout, return_when)
#     425     raise TypeError("Passing coroutines is forbidden, use tasks explicitly.")
#     427 loop = events.get_running_loop()
# --> 428 return await _wait(fs, timeout, return_when, loop)
#
# File /opt/anaconda3/lib/python3.11/asyncio/tasks.py:535, in _wait(fs, timeout, return_when, loop)
#     532     f.add_done_callback(_on_completion)
#     534 try:
# --> 535     await waiter
#     536 finally:
#     537     if timeout_handle is not None:
#
# File /opt/anaconda3/lib/python3.11/asyncio/futures.py:287, in Future.__await__(self)
#     285 if not self.done():
#     286     self._asyncio_future_blocking = True
# --> 287     yield self  # This tells Task to wait for completion.
#     288 if not self.done():
#     289     raise RuntimeError("await wasn't used with future")
#
# File /opt/anaconda3/lib/python3.11/asyncio/futures.py:198, in Future.result(self)
#     196 if self._state == _CANCELLED:
#     197     exc = self._make_cancelled_error()
# --> 198     raise exc
#     199 if self._state != _FINISHED:
#     200     raise exceptions.InvalidStateError('Result is not ready.')
#
# CancelledError:
